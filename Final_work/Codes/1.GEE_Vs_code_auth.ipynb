# %% [markdown]
# ## Instalation of the libraries requiered and autentication with GEE

# %% [markdown]
# Several aspects must be considered:
#
# 1. If you have problems downloading images or linking with GEE, the '3.Modeling.ipynb' code can be run without the 'PS_Index.tif'file.
# 2. The file 'PS_Index_filtered.tif' is already in the repository, so you can avoid executing the download of point 5.
# 3. The reason why the file 'PS_Index.tif' is not in the repository is because the file weighs more than 20MB (in this case 1.2 GB).
# 4. But you can download It using the link in the file 'PS_index.txt' in folder 'DataIntermediate'.

# %%
# %pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/159.8 MB ? eta -:--:--
#      ---------------------------------------- 0.3/159.8 MB 7.7 MB/s eta 0:00:21
#      --------------------------------------- 1.0/159.8 MB 12.2 MB/s eta 0:00:14
#       -------------------------------------- 2.2/159.8 MB 17.1 MB/s eta 0:00:10
#       -------------------------------------- 3.2/159.8 MB 18.5 MB/s eta 0:00:09
#      - ------------------------------------- 4.3/159.8 MB 19.4 MB/s eta 0:00:09
#      - ------------------------------------- 5.3/159.8 MB 19.8 MB/s eta 0:00:08
#      - ------------------------------------- 6.4/159.8 MB 20.4 MB/s eta 0:00:08
#      - ------------------------------------- 7.1/159.8 MB 19.7 MB/s eta 0:00:08
#      - ------------------------------------- 8.1/159.8 MB 20.0 MB/s eta 0:00:08
#      -- ------------------------------------ 9.1/159.8 MB 20.1 MB/s eta 0:00:08
#      -- ----------------------------------- 10.1/159.8 MB 20.1 MB/s eta 0:00:08
# ...

# %%
import os
import json
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
import google.auth

# Path to the JSON file with the credentials
credentials_path = 'C:/Users/cespe/client_secret_775448020170-552oojetfaabv5mcd26hs7j281prngoq.apps.googleusercontent.com.json'
token_path = 'token.json'

# Authentication using OAuth 2.0 client credentials
def get_credentials():
    credentials = None
    if os.path.exists(token_path):
        with open(token_path, 'r') as token_file:
            credentials = google.oauth2.credentials.Credentials.from_authorized_user_info(
                json.load(token_file)
            )

    if not credentials or not credentials.valid:
        if credentials and credentials.expired and credentials.refresh_token:
            credentials.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                credentials_path,
                scopes=['https://www.googleapis.com/auth/cloud-platform']
            )
            credentials = flow.run_local_server(port=0)

        # Guarda las credenciales para la próxima ejecución
        with open(token_path, 'w') as token_file:
            token_file.write(credentials.to_json())

    return credentials

credentials = get_credentials()


print("Authentication successful")
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=775448020170-552oojetfaabv5mcd26hs7j281prngoq.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A64473%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform&state=eiRR21adMaEAoPXBAxY2ms8w775qlA&access_type=offline
# Autenticación exitosa
